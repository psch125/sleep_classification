# %%
from PIL import Image
import tensorflow as tf
import os, glob, numpy as np
from sklearn.model_selection import train_test_split
import os, glob, numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  # 텐서플로가 첫 번째 GPU에 1GB 메모리만 할당하도록 제한
  try:
    tf.config.experimental.set_virtual_device_configuration(
        gpus[0],
        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=1024)])
  except RuntimeError as e:
    # 프로그램 시작시에 가상 장치가 설정되어야만 합니다
    print(e)

# %%
myFile = open("C:/Users/PC/표/sleep_file/새 폴더/EDF_Data/R/R_data/001_1.txt",'r')
lines = myFile.readlines()
n=len(lines)
text=[]
date=[] 
hour=[] 
mi=[]   
sec=[]
eeg=[]
eog=[]


for line in lines :
    text =line.split()
    date.append(text[0]) 
    hour.append(text[1])
    mi.append(text[2])
    sec.append(text[3])
    eeg.append(text[4])
    eog.append(text[5])
myFile.close()


fmax = 100      # 주파수 샘플링
dt = 1/fmax     # dt
N  = 3000    # 신호 길이

x=[]
y=[]
z=[]

for i in range(0,3000):
    x.append(i)
    y.append(eeg[i])
    z.append(eog[i])
              
y_a=[float(num) for num in y]
    
df = fmax/N
f = np.arange(0,N)*df
xf = np.fft.fft(y_a)*dt
plt.plot(f[0:int(N/2+1)],np.abs(xf[0:int(N/2+1)]))
plt.axis('off'), plt.xticks([]), plt.yticks([])
plt.grid()
plt.tight_layout()

# %%
plt.plot(f,np.abs(xf))

# %%
from PIL import Image
import tensorflow as tf
import os, glob, numpy as np
from sklearn.model_selection import train_test_split
import os, glob, numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
# %matplotlib inline 



# gpus = tf.config.experimental.list_physical_devices('GPU')
# if gpus:
#   try:
#     for gpu in gpus:
#       tf.config.experimental.set_memory_growth(gpu, True)
#       logical_gpus = tf.config.experimental.list_logical_devices('GPU')
#       print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
#   except RuntimeError as e:
#     print(e)

X_train, X_test, y_train, y_test = np.load("C:/Users/PC/표/cnn_eeg/sklearn_dataset2/eeg+eog.npy",allow_pickle=True)
print(X_train.shape)
print(X_train.shape[0])
print(X_test.shape)
# categories =["1_emg", "2_emg","3_emg","R_emg"]
categories =["1_eeg+eog","2_eeg+eog", "3_eeg+eog","R_eeg+eog"]
nb_classes = len(categories)

#일반화
X_train = X_train.astype(float) / 255
X_test = X_test.astype(float) / 255

# strategy = tf.distribute.MirroredStrategy()
mirrored_strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0","/gpu:1","/gpu:2","/gpu:3"],
                     cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())

with mirrored_strategy.scope():
    model = Sequential()
    model.add(Conv2D(32, (3,3), padding="same", input_shape=X_train.shape[1:], activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3,3), padding="same", activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model_dir = 'C:/Users/PC/표/model'

if not os.path.exists(model_dir):
    os.mkdir(model_dir)

model_path = model_dir + '/eeg'
checkpoint = ModelCheckpoint(filepath=model_path , monitor='val_loss', verbose=1, save_best_only=True)
early_stopping = EarlyStopping(monitor='val_loss', patience=6)


model.summary()
history = model.fit(X_train, y_train, batch_size=32, epochs=50, validation_split=0.2, callbacks=[checkpoint, early_stopping])
print("정확도 : %.4f" % (model.evaluate(X_test, y_test)[1]))
y_loss = history.history['loss']

x_len = np.arange(len(y_loss))


model.save('model_eeg+eog')

# plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
epochs = 'epochs'
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
# plt.legend(['loss','val_loss', 'accuracy','val_accuracy'])
plt.legend(['accuracy','val_accuracy'])
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.ylim([0.5,1])
plt.grid()
plt.show()

from sklearn.metrics import classification_report,confusion_matrix

y_pred = model.predict(X_test)
y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)

print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
# (3000, 144, 216, 3)
# 3000
# (1000, 144, 216, 3)
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2', '/job:localhost/replica:0/task:0/device:GPU:3')
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 144, 216, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 72, 108, 32)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 72, 108, 32)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 108, 64)       18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 54, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 36, 54, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 124416)            0
# _________________________________________________________________
# dense (Dense)                (None, 256)               31850752
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 1028
# =================================================================
# Total params: 31,871,172
# Trainable params: 31,871,172
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# INFO:tensorflow:batch_all_reduce: 8 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:batch_all_reduce: 8 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 75/75 [==============================] - ETA: 0s - loss: 2.6994 - accuracy: 0.4733INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
#
# Epoch 00001: val_loss improved from inf to 0.94137, saving model to C:/Users/PC/표/model/eeg
# WARNING:tensorflow:From C:\Users\PC\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:1813: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: C:/Users/PC/표/model/eeg\assets
# 75/75 [==============================] - 13s 171ms/step - loss: 2.6994 - accuracy: 0.4733 - val_loss: 0.9414 - val_accuracy: 0.6633
# Epoch 2/50
# 75/75 [==============================] - ETA: 0s - loss: 0.6697 - accuracy: 0.7550
# Epoch 00002: val_loss improved from 0.94137 to 0.55642, saving model to C:/Users/PC/표/model/eeg
# INFO:tensorflow:Assets written to: C:/Users/PC/표/model/eeg\assets
# 75/75 [==============================] - 11s 143ms/step - loss: 0.6697 - accuracy: 0.7550 - val_loss: 0.5564 - val_accuracy: 0.7667
# Epoch 3/50
# 75/75 [==============================] - ETA: 0s - loss: 0.4691 - accuracy: 0.8279
# Epoch 00003: val_loss improved from 0.55642 to 0.46942, saving model to C:/Users/PC/표/model/eeg
# INFO:tensorflow:Assets written to: C:/Users/PC/표/model/eeg\assets
# 75/75 [==============================] - 11s 144ms/step - loss: 0.4691 - accuracy: 0.8279 - val_loss: 0.4694 - val_accuracy: 0.8183
# Epoch 4/50
# 75/75 [==============================] - ETA: 0s - loss: 0.3920 - accuracy: 0.8471
# Epoch 00004: val_loss did not improve from 0.46942
# 75/75 [==============================] - 9s 113ms/step - loss: 0.3920 - accuracy: 0.8471 - val_loss: 0.4947 - val_accuracy: 0.7833
# Epoch 5/50
# 75/75 [==============================] - ETA: 0s - loss: 0.3322 - accuracy: 0.8721
# Epoch 00005: val_loss improved from 0.46942 to 0.43254, saving model to C:/Users/PC/표/model/eeg
# INFO:tensorflow:Assets written to: C:/Users/PC/표/model/eeg\assets
# 75/75 [==============================] - 11s 145ms/step - loss: 0.3322 - accuracy: 0.8721 - val_loss: 0.4325 - val_accuracy: 0.8367
# Epoch 6/50
# 75/75 [==============================] - ETA: 0s - loss: 0.2975 - accuracy: 0.8925
# Epoch 00006: val_loss did not improve from 0.43254
# 75/75 [==============================] - 9s 114ms/step - loss: 0.2975 - accuracy: 0.8925 - val_loss: 0.5028 - val_accuracy: 0.8317
# Epoch 7/50
# 75/75 [==============================] - ETA: 0s - loss: 0.2472 - accuracy: 0.9108
# Epoch 00007: val_loss did not improve from 0.43254
# 75/75 [==============================] - 8s 113ms/step - loss: 0.2472 - accuracy: 0.9108 - val_loss: 0.5220 - val_accuracy: 0.8233
# Epoch 8/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1982 - accuracy: 0.9267
# Epoch 00008: val_loss did not improve from 0.43254
# 75/75 [==============================] - 8s 113ms/step - loss: 0.1982 - accuracy: 0.9267 - val_loss: 0.5638 - val_accuracy: 0.8100
# Epoch 9/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1762 - accuracy: 0.9392
# Epoch 00009: val_loss did not improve from 0.43254
# 75/75 [==============================] - 8s 113ms/step - loss: 0.1762 - accuracy: 0.9392 - val_loss: 0.5861 - val_accuracy: 0.8200
# Epoch 10/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1275 - accuracy: 0.9558
# Epoch 00010: val_loss did not improve from 0.43254
# 75/75 [==============================] - 9s 113ms/step - loss: 0.1275 - accuracy: 0.9558 - val_loss: 0.6574 - val_accuracy: 0.8150
# Epoch 11/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1219 - accuracy: 0.9571
# Epoch 00011: val_loss did not improve from 0.43254
# 75/75 [==============================] - 9s 114ms/step - loss: 0.1219 - accuracy: 0.9571 - val_loss: 0.6254 - val_accuracy: 0.8267
# 32/32 [==============================] - 0s 9ms/step - loss: 0.4947 - accuracy: 0.8590
# 정확도 : 0.8590
# INFO:tensorflow:Assets written to: model_eeg+eog\assets
#               precision    recall  f1-score   support
#
#            0       0.77      0.48      0.59       144
#            1       0.84      0.96      0.90       461
#            2       0.99      1.00      1.00       233
#            3       0.78      0.70      0.74       162
#
#     accuracy                           0.86      1000
#    macro avg       0.84      0.78      0.80      1000
# weighted avg       0.85      0.86      0.85      1000
#
# [[ 69  53   0  22]
#  [  8 444   0   9]
#  [  0   0 233   0]
#  [ 13  34   2 113]]

# %%
from PIL import Image
import tensorflow as tf
import os, glob, numpy as np
from sklearn.model_selection import train_test_split
import os, glob, numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
# %matplotlib inline 



# gpus = tf.config.experimental.list_physical_devices('GPU')
# if gpus:
#   try:
#     for gpu in gpus:
#       tf.config.experimental.set_memory_growth(gpu, True)
#       logical_gpus = tf.config.experimental.list_logical_devices('GPU')
#       print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
#   except RuntimeError as e:
#     print(e)

X_train, X_test, y_train, y_test = np.load("C:/Users/PC/표/cnn_eeg/sklearn_dataset2/eeg_fft+eog_fft.npy",allow_pickle=True)
print(X_train.shape)
print(X_train.shape[0])
print(X_test.shape)
# categories =["1_emg", "2_emg","3_emg","R_emg"]
categories =["1_eeg_fft+eog_fft","2_eeg_fft+eog_fft", "3_eeg_fft+eog_fft","R_eeg_fft+eog_fft"]
nb_classes = len(categories)

#일반화
X_train = X_train.astype(float) / 255
X_test = X_test.astype(float) / 255

# strategy = tf.distribute.MirroredStrategy()
mirrored_strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0","/gpu:1","/gpu:2","/gpu:3"],
                     cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())

with mirrored_strategy.scope():
    model = Sequential()
    model.add(Conv2D(32, (3,3), padding="same", input_shape=X_train.shape[1:], activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3,3), padding="same", activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model_dir = 'C:/Users/PC/표/model'

if not os.path.exists(model_dir):
    os.mkdir(model_dir)

model_path = model_dir + '/eeg'
checkpoint = ModelCheckpoint(filepath=model_path , monitor='val_loss', verbose=1, save_best_only=True)
early_stopping = EarlyStopping(monitor='val_loss', patience=6)


model.summary()
history = model.fit(X_train, y_train, batch_size=32, epochs=50, validation_split=0.2, callbacks=[checkpoint, early_stopping])
print("정확도 : %.4f" % (model.evaluate(X_test, y_test)[1]))
y_loss = history.history['loss']

x_len = np.arange(len(y_loss))


model.save('model_eeg_fft+eog_fft')

# plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
eeg_eog_fft_accuracy = history.history['accuracy']
eeg_eog_fft_val_accuracy = history.history['val_accuracy']
eeg_eog_fft_epochs = 'epochs'
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
# plt.legend(['loss','val_loss', 'accuracy','val_accuracy'])
plt.legend(['accuracy','val_accuracy'])
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.ylim([0.5,1])
plt.grid()
plt.show()

from sklearn.metrics import classification_report,confusion_matrix

y_pred = model.predict(X_test)
y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)

print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
# (3000, 144, 216, 3)
# 3000
# (1000, 144, 216, 3)
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2', '/job:localhost/replica:0/task:0/device:GPU:3')
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 144, 216, 32)      896
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 72, 108, 32)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 72, 108, 32)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 72, 108, 64)       18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 36, 54, 64)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 36, 54, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 124416)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               31850752
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 1028
# =================================================================
# Total params: 31,871,172
# Trainable params: 31,871,172
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# INFO:tensorflow:batch_all_reduce: 8 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 8 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# 75/75 [==============================] - ETA: 0s - loss: 2.8576 - accuracy: 0.5183
# Epoch 00001: val_loss improved from inf to 0.72819, saving model to C:/Users/PC/표/model/eeg
# INFO:tensorflow:Assets written to: C:/Users/PC/표/model/eeg\assets
# 75/75 [==============================] - 13s 167ms/step - loss: 2.8576 - accuracy: 0.5183 - val_loss: 0.7282 - val_accuracy: 0.7233
# Epoch 2/50
# 75/75 [==============================] - ETA: 0s - loss: 0.6134 - accuracy: 0.7683
# Epoch 00002: val_loss improved from 0.72819 to 0.50251, saving model to C:/Users/PC/표/model/eeg
# INFO:tensorflow:Assets written to: C:/Users/PC/표/model/eeg\assets
# 75/75 [==============================] - 11s 145ms/step - loss: 0.6134 - accuracy: 0.7683 - val_loss: 0.5025 - val_accuracy: 0.8200
# Epoch 3/50
# 75/75 [==============================] - ETA: 0s - loss: 0.4743 - accuracy: 0.8179
# Epoch 00003: val_loss improved from 0.50251 to 0.42334, saving model to C:/Users/PC/표/model/eeg
# INFO:tensorflow:Assets written to: C:/Users/PC/표/model/eeg\assets
# 75/75 [==============================] - 11s 140ms/step - loss: 0.4743 - accuracy: 0.8179 - val_loss: 0.4233 - val_accuracy: 0.8500
# Epoch 4/50
# 75/75 [==============================] - ETA: 0s - loss: 0.3982 - accuracy: 0.8467
# Epoch 00004: val_loss improved from 0.42334 to 0.38580, saving model to C:/Users/PC/표/model/eeg
# INFO:tensorflow:Assets written to: C:/Users/PC/표/model/eeg\assets
# 75/75 [==============================] - 11s 144ms/step - loss: 0.3982 - accuracy: 0.8467 - val_loss: 0.3858 - val_accuracy: 0.8517
# Epoch 5/50
# 75/75 [==============================] - ETA: 0s - loss: 0.3784 - accuracy: 0.8450
# Epoch 00005: val_loss improved from 0.38580 to 0.36284, saving model to C:/Users/PC/표/model/eeg
# INFO:tensorflow:Assets written to: C:/Users/PC/표/model/eeg\assets
# 75/75 [==============================] - 11s 144ms/step - loss: 0.3784 - accuracy: 0.8450 - val_loss: 0.3628 - val_accuracy: 0.8667
# Epoch 6/50
# 75/75 [==============================] - ETA: 0s - loss: 0.3478 - accuracy: 0.8712
# Epoch 00006: val_loss improved from 0.36284 to 0.32673, saving model to C:/Users/PC/표/model/eeg
# INFO:tensorflow:Assets written to: C:/Users/PC/표/model/eeg\assets
# 75/75 [==============================] - 11s 145ms/step - loss: 0.3478 - accuracy: 0.8712 - val_loss: 0.3267 - val_accuracy: 0.8833
# Epoch 7/50
# 75/75 [==============================] - ETA: 0s - loss: 0.3396 - accuracy: 0.8708
# Epoch 00007: val_loss did not improve from 0.32673
# 75/75 [==============================] - 9s 115ms/step - loss: 0.3396 - accuracy: 0.8708 - val_loss: 0.3489 - val_accuracy: 0.8717
# Epoch 8/50
# 75/75 [==============================] - ETA: 0s - loss: 0.3180 - accuracy: 0.8771
# Epoch 00008: val_loss improved from 0.32673 to 0.31908, saving model to C:/Users/PC/표/model/eeg
# INFO:tensorflow:Assets written to: C:/Users/PC/표/model/eeg\assets
# 75/75 [==============================] - 11s 145ms/step - loss: 0.3180 - accuracy: 0.8771 - val_loss: 0.3191 - val_accuracy: 0.8850
# Epoch 9/50
# 75/75 [==============================] - ETA: 0s - loss: 0.3057 - accuracy: 0.8767
# Epoch 00009: val_loss did not improve from 0.31908
# 75/75 [==============================] - 8s 113ms/step - loss: 0.3057 - accuracy: 0.8767 - val_loss: 0.3251 - val_accuracy: 0.8783
# Epoch 10/50
# 75/75 [==============================] - ETA: 0s - loss: 0.2952 - accuracy: 0.8842
# Epoch 00010: val_loss improved from 0.31908 to 0.30034, saving model to C:/Users/PC/표/model/eeg
# INFO:tensorflow:Assets written to: C:/Users/PC/표/model/eeg\assets
# 75/75 [==============================] - 11s 144ms/step - loss: 0.2952 - accuracy: 0.8842 - val_loss: 0.3003 - val_accuracy: 0.8817
# Epoch 11/50
# 75/75 [==============================] - ETA: 0s - loss: 0.2527 - accuracy: 0.9046
# Epoch 00011: val_loss did not improve from 0.30034
# 75/75 [==============================] - 9s 113ms/step - loss: 0.2527 - accuracy: 0.9046 - val_loss: 0.3246 - val_accuracy: 0.8833
# Epoch 12/50
# 75/75 [==============================] - ETA: 0s - loss: 0.2524 - accuracy: 0.9046
# Epoch 00012: val_loss did not improve from 0.30034
# 75/75 [==============================] - 8s 113ms/step - loss: 0.2524 - accuracy: 0.9046 - val_loss: 0.3470 - val_accuracy: 0.8817
# Epoch 13/50
# 75/75 [==============================] - ETA: 0s - loss: 0.2501 - accuracy: 0.9083
# Epoch 00013: val_loss did not improve from 0.30034
# 75/75 [==============================] - 9s 114ms/step - loss: 0.2501 - accuracy: 0.9083 - val_loss: 0.3198 - val_accuracy: 0.8850
# Epoch 14/50
# 75/75 [==============================] - ETA: 0s - loss: 0.2403 - accuracy: 0.9025
# Epoch 00014: val_loss did not improve from 0.30034
# 75/75 [==============================] - 9s 113ms/step - loss: 0.2403 - accuracy: 0.9025 - val_loss: 0.3289 - val_accuracy: 0.8917
# Epoch 15/50
# 75/75 [==============================] - ETA: 0s - loss: 0.2252 - accuracy: 0.9137
# Epoch 00015: val_loss did not improve from 0.30034
# 75/75 [==============================] - 9s 114ms/step - loss: 0.2252 - accuracy: 0.9137 - val_loss: 0.3196 - val_accuracy: 0.8967
# Epoch 16/50
# 75/75 [==============================] - ETA: 0s - loss: 0.2175 - accuracy: 0.9196
# Epoch 00016: val_loss did not improve from 0.30034
# 75/75 [==============================] - 9s 114ms/step - loss: 0.2175 - accuracy: 0.9196 - val_loss: 0.3570 - val_accuracy: 0.8867
# 32/32 [==============================] - 0s 6ms/step - loss: 0.3765 - accuracy: 0.8650
# 정확도 : 0.8650
# INFO:tensorflow:Assets written to: model_eeg_fft+eog_fft\assets
#               precision    recall  f1-score   support
#
#            0       0.78      0.48      0.60       147
#            1       0.85      0.95      0.90       424
#            2       0.96      0.97      0.97       225
#            3       0.83      0.84      0.84       204
#
#     accuracy                           0.86      1000
#    macro avg       0.86      0.81      0.83      1000
# weighted avg       0.86      0.86      0.86      1000
#
# [[ 71  51   0  25]
#  [  5 403   8   8]
#  [  0   5 219   1]
#  [ 15  17   0 172]]

# %%
plt.plot(eeg_eog_fft_accuracy)
plt.plot(eeg_eog_fft_val_accuracy)
# plt.legend(['loss','val_loss', 'accuracy','val_accuracy'])
plt.legend(['accuracy','val_accuracy'])
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.ylim([0.5,1])
plt.grid()
plt.show()

# %%
from PIL import Image
import tensorflow as tf
import os, glob, numpy as np
from sklearn.model_selection import train_test_split
import os, glob, numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
# %matplotlib inline 



# gpus = tf.config.experimental.list_physical_devices('GPU')
# if gpus:
#   try:
#     for gpu in gpus:
#       tf.config.experimental.set_memory_growth(gpu, True)
#       logical_gpus = tf.config.experimental.list_logical_devices('GPU')
#       print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
#   except RuntimeError as e:
#     print(e)

X_train, X_test, y_train, y_test = np.load("C:/Users/PC/표/cnn_eeg/sklearn_dataset2/eeg+eeg_fft+eog+eog_fft.npy",allow_pickle=True)
print(X_train.shape)
print(X_train.shape[0])
print(X_test.shape)
# categories =["1_emg", "2_emg","3_emg","R_emg"]
categories =["1+1","2+2", "3+3","R+R"]
nb_classes = len(categories)

#일반화
X_train = X_train.astype(float) / 255
X_test = X_test.astype(float) / 255

# strategy = tf.distribute.MirroredStrategy()
mirrored_strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0","/gpu:1","/gpu:2","/gpu:3"],
                     cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())

with mirrored_strategy.scope():
    model = Sequential()
    model.add(Conv2D(32, (3,3), padding="same", input_shape=X_train.shape[1:], activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3,3), padding="same", activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model_dir = 'C:/Users/PC/표/model'

if not os.path.exists(model_dir):
    os.mkdir(model_dir)

model_path = model_dir + '/eeg'
checkpoint = ModelCheckpoint(filepath=model_path , monitor='val_loss', verbose=1, save_best_only=True)
early_stopping = EarlyStopping(monitor='val_loss', patience=6)


model.summary()
history = model.fit(X_train, y_train, batch_size=32, epochs=50, validation_split=0.2, callbacks=[checkpoint, early_stopping])
print("정확도 : %.4f" % (model.evaluate(X_test, y_test)[1]))
y_loss = history.history['loss']

x_len = np.arange(len(y_loss))


model.save('model_eeg+eeg_fft+eog+eog_fft')

# plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
three_accuracy = history.history['accuracy']
three_val_accuracy = history.history['val_accuracy']
three_epochs = 'epochs'
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
# plt.legend(['loss','val_loss', 'accuracy','val_accuracy'])
plt.legend(['accuracy','val_accuracy'])
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.ylim([0.5,1])
plt.grid()
plt.show()

from sklearn.metrics import classification_report,confusion_matrix

y_pred = model.predict(X_test)
y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)

print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
# (3000, 144, 216, 3)
# 3000
# (1000, 144, 216, 3)
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2', '/job:localhost/replica:0/task:0/device:GPU:3')
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 144, 216, 32)      896
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 72, 108, 32)       0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 72, 108, 32)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 72, 108, 64)       18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 36, 54, 64)        0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 36, 54, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 124416)            0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               31850752
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 1028
# =================================================================
# Total params: 31,871,172
# Trainable params: 31,871,172
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# INFO:tensorflow:batch_all_reduce: 8 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 8 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# 75/75 [==============================] - ETA: 0s - loss: 2.3202 - accuracy: 0.6842
# Epoch 00001: val_loss improved from inf to 0.26351, saving model to C:/Users/PC/표/model/eeg
# INFO:tensorflow:Assets written to: C:/Users/PC/표/model/eeg\assets
# 75/75 [==============================] - 12s 154ms/step - loss: 2.3202 - accuracy: 0.6842 - val_loss: 0.2635 - val_accuracy: 0.9067
# Epoch 2/50
# 75/75 [==============================] - ETA: 0s - loss: 0.2205 - accuracy: 0.8992
# Epoch 00002: val_loss improved from 0.26351 to 0.17779, saving model to C:/Users/PC/표/model/eeg
# INFO:tensorflow:Assets written to: C:/Users/PC/표/model/eeg\assets
# 75/75 [==============================] - 11s 143ms/step - loss: 0.2205 - accuracy: 0.8992 - val_loss: 0.1778 - val_accuracy: 0.9317
# Epoch 3/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1622 - accuracy: 0.9296
# Epoch 00003: val_loss improved from 0.17779 to 0.15734, saving model to C:/Users/PC/표/model/eeg
# INFO:tensorflow:Assets written to: C:/Users/PC/표/model/eeg\assets
# 75/75 [==============================] - 11s 144ms/step - loss: 0.1622 - accuracy: 0.9296 - val_loss: 0.1573 - val_accuracy: 0.9400
# Epoch 4/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1430 - accuracy: 0.9408
# Epoch 00004: val_loss did not improve from 0.15734
# 75/75 [==============================] - 8s 112ms/step - loss: 0.1430 - accuracy: 0.9408 - val_loss: 0.1610 - val_accuracy: 0.9283
# Epoch 5/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1263 - accuracy: 0.9475
# Epoch 00005: val_loss did not improve from 0.15734
# 75/75 [==============================] - 8s 112ms/step - loss: 0.1263 - accuracy: 0.9475 - val_loss: 0.1627 - val_accuracy: 0.9317
# Epoch 6/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1065 - accuracy: 0.9583 ETA: 0s - loss: 0.1063 - accu
# Epoch 00006: val_loss improved from 0.15734 to 0.15423, saving model to C:/Users/PC/표/model/eeg
# INFO:tensorflow:Assets written to: C:/Users/PC/표/model/eeg\assets
# 75/75 [==============================] - 11s 143ms/step - loss: 0.1065 - accuracy: 0.9583 - val_loss: 0.1542 - val_accuracy: 0.9400
# Epoch 7/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0953 - accuracy: 0.9604
# Epoch 00007: val_loss improved from 0.15423 to 0.14114, saving model to C:/Users/PC/표/model/eeg
# INFO:tensorflow:Assets written to: C:/Users/PC/표/model/eeg\assets
# 75/75 [==============================] - 10s 139ms/step - loss: 0.0953 - accuracy: 0.9604 - val_loss: 0.1411 - val_accuracy: 0.9450
# Epoch 8/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0889 - accuracy: 0.9642
# Epoch 00008: val_loss did not improve from 0.14114
# 75/75 [==============================] - 8s 113ms/step - loss: 0.0889 - accuracy: 0.9642 - val_loss: 0.1582 - val_accuracy: 0.9333
# Epoch 9/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0861 - accuracy: 0.9650
# Epoch 00009: val_loss improved from 0.14114 to 0.14077, saving model to C:/Users/PC/표/model/eeg
# INFO:tensorflow:Assets written to: C:/Users/PC/표/model/eeg\assets
# 75/75 [==============================] - 11s 143ms/step - loss: 0.0861 - accuracy: 0.9650 - val_loss: 0.1408 - val_accuracy: 0.9433
# Epoch 10/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0940 - accuracy: 0.9621
# Epoch 00010: val_loss did not improve from 0.14077
# 75/75 [==============================] - 8s 113ms/step - loss: 0.0940 - accuracy: 0.9621 - val_loss: 0.1436 - val_accuracy: 0.9450
# Epoch 11/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0767 - accuracy: 0.9725 ETA: 0s - loss: 0.0782
# Epoch 00011: val_loss did not improve from 0.14077
# 75/75 [==============================] - 8s 112ms/step - loss: 0.0767 - accuracy: 0.9725 - val_loss: 0.1553 - val_accuracy: 0.9417
# Epoch 12/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0694 - accuracy: 0.9725
# Epoch 00012: val_loss did not improve from 0.14077
# 75/75 [==============================] - 8s 113ms/step - loss: 0.0694 - accuracy: 0.9725 - val_loss: 0.1983 - val_accuracy: 0.9333
# Epoch 13/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0643 - accuracy: 0.9758
# Epoch 00013: val_loss did not improve from 0.14077
# 75/75 [==============================] - 9s 117ms/step - loss: 0.0643 - accuracy: 0.9758 - val_loss: 0.1809 - val_accuracy: 0.9500
# Epoch 14/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0590 - accuracy: 0.9779
# Epoch 00014: val_loss did not improve from 0.14077
# 75/75 [==============================] - 8s 112ms/step - loss: 0.0590 - accuracy: 0.9779 - val_loss: 0.1753 - val_accuracy: 0.9417
# Epoch 15/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0501 - accuracy: 0.9792
# Epoch 00015: val_loss did not improve from 0.14077
# 75/75 [==============================] - 8s 112ms/step - loss: 0.0501 - accuracy: 0.9792 - val_loss: 0.2050 - val_accuracy: 0.9317
# 32/32 [==============================] - 0s 6ms/step - loss: 0.1646 - accuracy: 0.9440
# 정확도 : 0.9440
# INFO:tensorflow:Assets written to: model_eeg+eeg_fft+eog+eog_fft\assets
#               precision    recall  f1-score   support
#
#            0       0.78      0.91      0.84       158
#            1       1.00      1.00      1.00       440
#            2       1.00      1.00      1.00       212
#            3       0.91      0.78      0.84       190
#
#     accuracy                           0.94      1000
#    macro avg       0.92      0.92      0.92      1000
# weighted avg       0.95      0.94      0.94      1000
#
# [[143   0   0  15]
#  [  0 440   0   0]
#  [  0   0 212   0]
#  [ 41   0   0 149]]

# %%
from PIL import Image
import tensorflow as tf
import os, glob, numpy as np
from sklearn.model_selection import train_test_split
import os, glob, numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
# %matplotlib inline 



# gpus = tf.config.experimental.list_physical_devices('GPU')
# if gpus:
#   try:
#     for gpu in gpus:
#       tf.config.experimental.set_memory_growth(gpu, True)
#       logical_gpus = tf.config.experimental.list_logical_devices('GPU')
#       print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
#   except RuntimeError as e:
#     print(e)

X_train, X_test, y_train, y_test = np.load("C:/Users/PC/표/cnn_eeg/sklearn_dataset2/eeg_fft+eog_fft.npy",allow_pickle=True)
print(X_train.shape)
print(X_train.shape[0])
print(X_test.shape)
# categories =["1_emg", "2_emg","3_emg","R_emg"]
categories =["1_eeg_fft+eog_fft","2_eeg_fft+eog_fft", "3_eeg_fft+eog_fft","R_eeg_fft+eog_fft"]
nb_classes = len(categories)

#일반화
X_train = X_train.astype(float) / 255
X_test = X_test.astype(float) / 255

# strategy = tf.distribute.MirroredStrategy()
mirrored_strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0","/gpu:1","/gpu:2","/gpu:3"],
                     cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())

with mirrored_strategy.scope():
    model = Sequential()
    model.add(Conv2D(32, (3,3), padding="same", input_shape=X_train.shape[1:], activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3,3), padding="same", activation='relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model_dir = 'C:/Users/PC/표/model'

if not os.path.exists(model_dir):
    os.mkdir(model_dir)

model_path = model_dir + '/eeg'
checkpoint = ModelCheckpoint(filepath=model_path , monitor='val_loss', verbose=1, save_best_only=True)
early_stopping = EarlyStopping(monitor='val_loss', patience=6)


model.summary()
history = model.fit(X_train, y_train, batch_size=32, epochs=50, validation_split=0.2, callbacks=[checkpoint, early_stopping])
print("정확도 : %.4f" % (model.evaluate(X_test, y_test)[1]))
y_loss = history.history['loss']

x_len = np.arange(len(y_loss))


model.save('model_eeg_fft+eog_fft')

# plt.plot(history.history['loss'])
# plt.plot(history.history['val_loss'])
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
# plt.legend(['loss','val_loss', 'accuracy','val_accuracy'])
plt.legend(['accuracy','val_accuracy'])
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.ylim([0.5,1])
plt.grid()
plt.show()

from sklearn.metrics import classification_report,confusion_matrix

y_pred = model.predict(X_test)
y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)

print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
# (3000, 144, 216, 3)
# 3000
# (1000, 144, 216, 3)
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1', '/job:localhost/replica:0/task:0/device:GPU:2', '/job:localhost/replica:0/task:0/device:GPU:3')
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 144, 216, 32)      896
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 72, 108, 32)       0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 72, 108, 32)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 72, 108, 64)       18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 36, 54, 64)        0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 36, 54, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 124416)            0
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               31850752
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 1028
# =================================================================
# Total params: 31,871,172
# Trainable params: 31,871,172
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# INFO:tensorflow:batch_all_reduce: 8 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 8 all-reduces with algorithm = hierarchical_copy, num_packs = 1
# 75/75 [==============================] - ETA: 0s - loss: 2.8316 - accuracy: 0.5133
# Epoch 00001: val_loss improved from inf to 0.77024, saving model to C:/Users/PC/표/model/eeg
# INFO:tensorflow:Assets written to: C:/Users/PC/표/model/eeg\assets
# 75/75 [==============================] - 12s 166ms/step - loss: 2.8316 - accuracy: 0.5133 - val_loss: 0.7702 - val_accuracy: 0.7400
# Epoch 2/50
# 75/75 [==============================] - ETA: 0s - loss: 0.6053 - accuracy: 0.7717
# Epoch 00002: val_loss improved from 0.77024 to 0.45947, saving model to C:/Users/PC/표/model/eeg
# INFO:tensorflow:Assets written to: C:/Users/PC/표/model/eeg\assets
# 75/75 [==============================] - 11s 144ms/step - loss: 0.6053 - accuracy: 0.7717 - val_loss: 0.4595 - val_accuracy: 0.8350
# Epoch 3/50
# 75/75 [==============================] - ETA: 0s - loss: 0.4584 - accuracy: 0.8204
# Epoch 00003: val_loss improved from 0.45947 to 0.40647, saving model to C:/Users/PC/표/model/eeg
# INFO:tensorflow:Assets written to: C:/Users/PC/표/model/eeg\assets
# 75/75 [==============================] - 11s 145ms/step - loss: 0.4584 - accuracy: 0.8204 - val_loss: 0.4065 - val_accuracy: 0.8467
# Epoch 4/50
# 75/75 [==============================] - ETA: 0s - loss: 0.4116 - accuracy: 0.8392
# Epoch 00004: val_loss improved from 0.40647 to 0.37000, saving model to C:/Users/PC/표/model/eeg
# INFO:tensorflow:Assets written to: C:/Users/PC/표/model/eeg\assets
# 75/75 [==============================] - 11s 144ms/step - loss: 0.4116 - accuracy: 0.8392 - val_loss: 0.3700 - val_accuracy: 0.8617
# Epoch 5/50
# 75/75 [==============================] - ETA: 0s - loss: 0.3793 - accuracy: 0.8558
# Epoch 00005: val_loss improved from 0.37000 to 0.35744, saving model to C:/Users/PC/표/model/eeg
# INFO:tensorflow:Assets written to: C:/Users/PC/표/model/eeg\assets
# 75/75 [==============================] - 11s 141ms/step - loss: 0.3793 - accuracy: 0.8558 - val_loss: 0.3574 - val_accuracy: 0.8750
# Epoch 6/50
# 75/75 [==============================] - ETA: 0s - loss: 0.3364 - accuracy: 0.8733
# Epoch 00006: val_loss improved from 0.35744 to 0.34697, saving model to C:/Users/PC/표/model/eeg
# INFO:tensorflow:Assets written to: C:/Users/PC/표/model/eeg\assets
# 75/75 [==============================] - 11s 145ms/step - loss: 0.3364 - accuracy: 0.8733 - val_loss: 0.3470 - val_accuracy: 0.8750
# Epoch 7/50
# 75/75 [==============================] - ETA: 0s - loss: 0.3329 - accuracy: 0.8700
# Epoch 00007: val_loss did not improve from 0.34697
# 75/75 [==============================] - 8s 112ms/step - loss: 0.3329 - accuracy: 0.8700 - val_loss: 0.3598 - val_accuracy: 0.8650
# Epoch 8/50
# 75/75 [==============================] - ETA: 0s - loss: 0.3077 - accuracy: 0.8733
# Epoch 00008: val_loss did not improve from 0.34697
# 75/75 [==============================] - 8s 113ms/step - loss: 0.3077 - accuracy: 0.8733 - val_loss: 0.3480 - val_accuracy: 0.8700
# Epoch 9/50
# 75/75 [==============================] - ETA: 0s - loss: 0.2955 - accuracy: 0.8842
# Epoch 00009: val_loss improved from 0.34697 to 0.32298, saving model to C:/Users/PC/표/model/eeg
# INFO:tensorflow:Assets written to: C:/Users/PC/표/model/eeg\assets
# 75/75 [==============================] - 11s 143ms/step - loss: 0.2955 - accuracy: 0.8842 - val_loss: 0.3230 - val_accuracy: 0.8817
# Epoch 10/50
# 75/75 [==============================] - ETA: 0s - loss: 0.2887 - accuracy: 0.8854
# Epoch 00010: val_loss did not improve from 0.32298
# 75/75 [==============================] - 8s 112ms/step - loss: 0.2887 - accuracy: 0.8854 - val_loss: 0.3278 - val_accuracy: 0.8733
# Epoch 11/50
# 75/75 [==============================] - ETA: 0s - loss: 0.2676 - accuracy: 0.8942
# Epoch 00011: val_loss did not improve from 0.32298
# 75/75 [==============================] - 8s 112ms/step - loss: 0.2676 - accuracy: 0.8942 - val_loss: 0.3232 - val_accuracy: 0.8717
# Epoch 12/50
# 75/75 [==============================] - ETA: 0s - loss: 0.2568 - accuracy: 0.8992
# Epoch 00012: val_loss did not improve from 0.32298
# 75/75 [==============================] - 8s 113ms/step - loss: 0.2568 - accuracy: 0.8992 - val_loss: 0.3704 - val_accuracy: 0.8633
# Epoch 13/50
# 75/75 [==============================] - ETA: 0s - loss: 0.2487 - accuracy: 0.9033
# Epoch 00013: val_loss did not improve from 0.32298
# 75/75 [==============================] - 8s 112ms/step - loss: 0.2487 - accuracy: 0.9033 - val_loss: 0.3346 - val_accuracy: 0.8733
# Epoch 14/50
# 75/75 [==============================] - ETA: 0s - loss: 0.2286 - accuracy: 0.9133
# Epoch 00014: val_loss improved from 0.32298 to 0.31049, saving model to C:/Users/PC/표/model/eeg
# INFO:tensorflow:Assets written to: C:/Users/PC/표/model/eeg\assets
# 75/75 [==============================] - 11s 144ms/step - loss: 0.2286 - accuracy: 0.9133 - val_loss: 0.3105 - val_accuracy: 0.8883
# Epoch 15/50
# 75/75 [==============================] - ETA: 0s - loss: 0.2047 - accuracy: 0.9171
# Epoch 00015: val_loss did not improve from 0.31049
# 75/75 [==============================] - 8s 112ms/step - loss: 0.2047 - accuracy: 0.9171 - val_loss: 0.3443 - val_accuracy: 0.8850
# Epoch 16/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1962 - accuracy: 0.9300
# Epoch 00016: val_loss did not improve from 0.31049
# 75/75 [==============================] - 8s 113ms/step - loss: 0.1962 - accuracy: 0.9300 - val_loss: 0.3193 - val_accuracy: 0.8933
# Epoch 17/50
# 75/75 [==============================] - ETA: 0s - loss: 0.2013 - accuracy: 0.9183
# Epoch 00017: val_loss did not improve from 0.31049
# 75/75 [==============================] - 8s 112ms/step - loss: 0.2013 - accuracy: 0.9183 - val_loss: 0.3391 - val_accuracy: 0.8750
# Epoch 18/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1922 - accuracy: 0.9271
# Epoch 00018: val_loss did not improve from 0.31049
# 75/75 [==============================] - 8s 111ms/step - loss: 0.1922 - accuracy: 0.9271 - val_loss: 0.3237 - val_accuracy: 0.8883
# Epoch 19/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1643 - accuracy: 0.9362
# Epoch 00019: val_loss did not improve from 0.31049
# 75/75 [==============================] - 9s 116ms/step - loss: 0.1643 - accuracy: 0.9362 - val_loss: 0.3254 - val_accuracy: 0.8833
# Epoch 20/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1702 - accuracy: 0.9321
# Epoch 00020: val_loss did not improve from 0.31049
# 75/75 [==============================] - 8s 112ms/step - loss: 0.1702 - accuracy: 0.9321 - val_loss: 0.3393 - val_accuracy: 0.8900
# 32/32 [==============================] - 0s 6ms/step - loss: 0.3379 - accuracy: 0.8830
# 정확도 : 0.8830
# INFO:tensorflow:Assets written to: model_eeg_fft+eog_fft\assets
#               precision    recall  f1-score   support
#
#            0       0.76      0.64      0.69       147
#            1       0.88      0.96      0.91       424
#            2       0.98      0.98      0.98       225
#            3       0.87      0.80      0.83       204
#
#     accuracy                           0.88      1000
#    macro avg       0.87      0.84      0.86      1000
# weighted avg       0.88      0.88      0.88      1000
#
# [[ 94  34   0  19]
#  [  9 405   5   5]
#  [  0   4 220   1]
#  [ 21  19   0 164]]

# %% [markdown]
# # from sklearn.ensemble import VotingClassifier

# %%
from PIL import Image
import tensorflow as tf
import os, glob, numpy as np
from sklearn.model_selection import train_test_split
import os, glob, numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
from sklearn.ensemble import VotingClassifier
# %matplotlib inline 



# gpus = tf.config.experimental.list_physical_devices('GPU')
# if gpus:
#   try:
#     for gpu in gpus:
#       tf.config.experimental.set_memory_growth(gpu, True)
#       logical_gpus = tf.config.experimental.list_logical_devices('GPU')
#       print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
#   except RuntimeError as e:
#     print(e)

X_train, X_test, y_train, y_test = np.load("C:/Users/PC/표/cnn_eeg/eog+eog_fft_4000.npy",allow_pickle=True)
print(X_train.shape)
print(X_train.shape[0])
# categories =["1_emg", "2_emg","3_emg","R_emg"]
categories =["1_eog+eog_fft","2_eog+eog_fft", "3_eog+eog_fft","R_eog+eog_fft"]
nb_classes = len(categories)

#일반화
X_train = X_train.astype(float) / 255
X_test = X_test.astype(float) / 255

# strategy = tf.distribute.MirroredStrategy()

# with strategy.scope():
model = Sequential()
model.add(Conv2D(32, (3,3), padding="same", input_shape=X_train.shape[1:], activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3,3), padding="same", activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(nb_classes, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model_dir = 'C:/Users/PC/표/model'

if not os.path.exists(model_dir):
    os.mkdir(model_dir)

model_path = model_dir + '/eog+eog_fft_test4000'
checkpoint = ModelCheckpoint(filepath=model_path , monitor='val_loss', verbose=1, save_best_only=True)
early_stopping = EarlyStopping(monitor='val_loss', patience=6)


model.summary()
history = model.fit(X_train, y_train, batch_size=32, epochs=50, validation_split=0.2, callbacks=[checkpoint, early_stopping])
print("정확도 : %.4f" % (model.evaluate(X_test, y_test)[1]))
y_loss = history.history['loss']

x_len = np.arange(len(y_loss))


model.save('model_1')

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['loss','val_loss', 'accuracy','val_accuracy'])
plt.xlabel('epochs')
plt.ylabel('loss')
plt.grid()
plt.show()

from sklearn.metrics import classification_report,confusion_matrix

y_pred = model.predict(X_test)
y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)

print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))

# %%
from tensorflow.keras.models import load_model
model = load_model('model_1')
model.summary()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['loss','val_loss', 'accuracy','val_accuracy'])
plt.xlabel('epochs')
plt.ylabel('loss')
plt.grid()
plt.show()
print("정확도 : %.4f" % (model.evaluate(X_test, y_test)[1]))

# %%
import pandas as pd

from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import load_model
model_1 = load_model('model/eeg_fft_test2')
model_2 = load_model('model/eog_fft_test4000')

# %%
model_1.summary()

# %%
model_2.summary()

# %%
print("정확도 : %.4f" % (model_1.evaluate(X_test, y_test)[1]))
print("정확도 : %.4f" % (model_2.evaluate(X_test, y_test)[1]))
