# %%
from PIL import Image
import os, glob, numpy as np
from sklearn.model_selection import train_test_split
import os, glob, numpy as np

from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
# %matplotlib inline 
caltech_dir = "C:/Users/PC/표/sleep_file/새 폴더/EDF_Data/"
# categories = ["1_emg", "2_emg", "3_emg","R_emg"]
categories =["1+1","2+2", "3+3","R+R"]
nb_classes = len(categories)

image_w = 216
image_h = 144

pixels = image_h * image_w * 3

X = []
y = []


for idx, cat in enumerate(categories):
    
    #one-hot 돌리기.
    label = [0 for i in range(nb_classes)]
    label[idx] = 1

    image_dir = caltech_dir + "/" + cat
    print(image_dir)
    files = glob.glob(image_dir+"/*.png")
    print(cat, " 파일 길이 : ", len(files))
    for i, f in enumerate(files):
        img = Image.open(f)
        img = img.convert("RGB")
        img = img.resize((image_w, image_h))
        data = np.asarray(img)

        X.append(data)
        y.append(label)

        if i % 70 == 0:
            print(cat, " : ", f)

X = np.array(X)
y = np.array(y)

#1 0 0 0 이면 airplanes
#0 1 0 0 이면 buddha 이런식

#X_train, X_test, y_train, y_test = train_test_split(X,y , shuffle = False, test_size = 0.1)
X_train, X_test, y_train, y_test = train_test_split(X, y)
xy = (X_train, X_test, y_train, y_test)

np.save("C:/Users/PC/표/sleep_file/새 폴더/EDF_Data/eeg+eeg_fft+eog+eog_fft.npy", xy)
# Out:
# C:/Users/PC/표/sleep_file/새 폴더/EDF_Data//1+1
# 1+1  파일 길이 :  600
# 1+1  :  C:/Users/PC/표/sleep_file/새 폴더/EDF_Data//1+1\4_61.png
# 1+1  :  C:/Users/PC/표/sleep_file/새 폴더/EDF_Data//1+1\5_6.png
# 1+1  :  C:/Users/PC/표/sleep_file/새 폴더/EDF_Data//1+1\7_108.png
# 1+1  :  C:/Users/PC/표/sleep_file/새 폴더/EDF_Data//1+1\7_171.png
# 1+1  :  C:/Users/PC/표/sleep_file/새 폴더/EDF_Data//1+1\7_80.png
# 1+1  :  C:/Users/PC/표/sleep_file/새 폴더/EDF_Data//1+1\8_3.png
# 1+1  :  C:/Users/PC/표/sleep_file/새 폴더/EDF_Data//1+1\8_93.png
# 1+1  :  C:/Users/PC/표/sleep_file/새 폴더/EDF_Data//1+1\9_156.png
# 1+1  :  C:/Users/PC/표/sleep_file/새 폴더/EDF_Data//1+1\9_63.png
# C:/Users/PC/표/sleep_file/새 폴더/EDF_Data//2+2
# 2+2  파일 길이 :  1800
# 2+2  :  C:/Users/PC/표/sleep_file/새 폴더/EDF_Data//2+2\3_120.png
# 2+2  :  C:/Users/PC/표/sleep_file/새 폴더/EDF_Data//2+2\3_184.png
# 2+2  :  C:/Users/PC/표/sleep_file/새 폴더/EDF_Data//2+2\3_25.png
# 2+2  :  C:/Users/PC/표/sleep_file/새 폴더/EDF_Data//2+2\3_89.png
# ...

# %%
import os
for filename in sorted(os.listdir("C:/Users/PC/표/sleep_file/새 폴더/EDF_Data/1+1"))[:-600]:
    filename_relPath = os.path.join("C:/Users/PC/표/sleep_file/새 폴더/EDF_Data/1+1",filename)
    os.remove(filename_relPath)
    

for filename in sorted(os.listdir("C:/Users/PC/표/sleep_file/새 폴더/EDF_Data/2+2"))[:-1800]:
    filename_relPath = os.path.join("C:/Users/PC/표/sleep_file/새 폴더/EDF_Data/2+2",filename)
    os.remove(filename_relPath)
    
for filename in sorted(os.listdir("C:/Users/PC/표/sleep_file/새 폴더/EDF_Data/3+3"))[:-880]:
    filename_relPath = os.path.join("C:/Users/PC/표/sleep_file/새 폴더/EDF_Data/3+3",filename)
    os.remove(filename_relPath)

for filename in sorted(os.listdir("C:/Users/PC/표/sleep_file/새 폴더/EDF_Data/R+R"))[:-720]:
    filename_relPath = os.path.join("C:/Users/PC/표/sleep_file/새 폴더/EDF_Data/R+R",filename)
    os.remove(filename_relPath)
